# %% [markdown]
# Perceptron is the building block of Neural Network.
# ---

# %%
from IPython.display import Image 
Image(filename='../img/perceptron.png', width=600, height=500)

# %% [markdown]
# **Perceptron Trick :** If one point is missclassified we will move the line little bit **closer** to the point. lets say we a point A(4,5) is missclassified we will multiply learning rate $a$ with the coordinate and subtract/add the value to the line to move it closer to the missclassified point.

# %% [markdown]
# To learn more about Neural Network checkout my another note [here](https://github.com/shohan4556/machine-learning-course-notes/blob/master/Notes/McCulloch%20and%20Pitts%20Model%20of%20ANN.md)
